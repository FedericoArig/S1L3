# %%
{
    "CD Musicale":{
        "Album":"X2VR",
        "Artista":"Sfera Ebbasta",
        "Genere":["Hip-hop","Trap"],
        "Canzoni":[
            
            {"Traccia":"1",
                "Titolo":"Fragile",
                "Durata":"2.25",
                
            },
            {"Traccia":"2",
                "Titolo":"Ciao Bella",
                "Durata":"3.00",
                "Feat":"Anna",
           },
            {"Traccia":"3",
                "Titolo":"G63",
                "Durata":"3.50",
                "Feat":["Lazza","Shiva"],
            },
            {"Traccia":"4",
                "Titolo":"VDLC",
                "Durata":"3.20",
                "Feat":"Guè",
            },
            {"Traccia":"5",
                "Titolo":"Anche Stasera",
                "Durata":"3.37",
                "Feat":"Elodie",
            },
            {"Traccia":"6",
                "Titolo":"Momenti No",
                "Durata":"3.12",
                "Feat":"Tedua",
            },
            {"Traccia":"7",
                "Titolo":"Milano Bene",
                "Durata":"2.42",
                
            },
            {"Traccia":"8",
                "Titolo":"3uphon",
                "Durata":"3.15",
                "Feat":["thasup","Tony Effe"],
            },
            {"Traccia":"9",
                "Titolo":"Complicato",
                "Durata":"3.13",
                "Feat":"Paky",
            },
            {"Traccia":"10",
                "Titolo":"Gol",
                "Durata":"3.37",
                "Feat":"Guè",
            },
            {"Traccia":"11",
                "Titolo":"Calcolatrici",
                "Durata":"3.25",
                "Feat":["Geolier","Simba La Rue","Baby Ganga"],
            },
            {"Traccia":"12",
                "Titolo":"15 Piani",
                "Durata":"3.26",
                "Feat":"Marracash",
            }
            
            
        ],
    }
    
}
# Out:
# {'CD Musicale': {'Album': 'X2VR',
#   'Artista': 'Sfera Ebbasta',
#   'Genere': ['Hip-hop', 'Trap'],
#   'Canzoni': [{'Traccia': '1', 'Titolo': 'Fragile', 'Durata': '2.25'},
#    {'Traccia': '2', 'Titolo': 'Ciao Bella', 'Durata': '3.00', 'Feat': 'Anna'},
#    {'Traccia': '3',
#     'Titolo': 'G63',
#     'Durata': '3.50',
#     'Feat': ['Lazza', 'Shiva']},
#    {'Traccia': '4', 'Titolo': 'VDLC', 'Durata': '3.20', 'Feat': 'Guè'},
#    {'Traccia': '5',
#     'Titolo': 'Anche Stasera',
#     'Durata': '3.37',
#     'Feat': 'Elodie'},
#    {'Traccia': '6', 'Titolo': 'Momenti No', 'Durata': '3.12', 'Feat': 'Tedua'},
#    {'Traccia': '7', 'Titolo': 'Milano Bene', 'Durata': '2.42'},
#    {'Traccia': '8',
#     'Titolo': '3uphon',
#     'Durata': '3.15',
#     'Feat': ['thasup', 'Tony Effe']},
#    {'Traccia': '9', 'Titolo': 'Complicato', 'Durata': '3.13', 'Feat': 'Paky'},
#    {'Traccia': '10', 'Titolo': 'Gol', 'Durata': '3.37', 'Feat': 'Guè'},
#    {'Traccia': '11',
# ...
